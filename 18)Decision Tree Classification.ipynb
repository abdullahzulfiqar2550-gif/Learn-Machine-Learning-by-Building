# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('exam1.csv')

# %%
data
# Out:
#    Youtube  guide result
# 0        0      0   fail
# 1        1      1   pass
# 2        1      0   pass
# 3        0      0   fail
# 4        0      0   fail
# 5        1      1   pass
# 6        0      1   fail
# 7        1      1   pass
# 8        1      0   fail
# 9        1      1   pass

# %%
data.result.value_counts()
# Out:
# result
# fail    5
# pass    5
# Name: count, dtype: int64

# %%
entropy_results = -(5/10)*np.log2(5/10) -(5/10)*np.log2(5/10)
entropy_results
# Out:
# np.float64(1.0)

# %%
data.rename(columns = {'Youtube':'yt'}, inplace = True)

# %%
data
# Out:
#    yt  guide result
# 0   0      0   fail
# 1   1      1   pass
# 2   1      0   pass
# 3   0      0   fail
# 4   0      0   fail
# 5   1      1   pass
# 6   0      1   fail
# 7   1      1   pass
# 8   1      0   fail
# 9   1      1   pass

# %%
data[data.yt == 1]
# Out:
#    yt  guide result
# 0   0      0   fail
# 1   1      1   pass
# 2   1      0   pass
# 3   0      0   fail
# 4   0      0   fail
# 5   1      1   pass
# 6   0      1   fail
# 7   1      1   pass
# 8   1      0   fail
# 9   1      1   pass

# %%
entropy_results_yt_yes = -(5/6)*np.log2(5/6) -(1/6)*np.log2(1/6)
entropy_results_yt_yes
# Out:
# np.float64(0.6500224216483541)

# %%
data[data.yt == 0]
# Out:
#    yt  guide result
# 0   0      0   fail
# 3   0      0   fail
# 4   0      0   fail
# 6   0      1   fail

# %%
#zero

# %%
yt_entropy = (6/10) * entropy_results_yt_yes +  (4/10) * 0
yt_entropy
# Out:
# np.float64(0.39001345298901247)

# %%
info_yt = entropy_results - (6/10) * entropy_results_yt_yes -  (4/10) * 0
info_yt
# Out:
# np.float64(0.6099865470109875)

# %%
data[data.guide == 1]
data.head(10)
# Out:
#    yt  guide result
# 0   0      0   fail
# 1   1      1   pass
# 2   1      0   pass
# 3   0      0   fail
# 4   0      0   fail
# 5   1      1   pass
# 6   0      1   fail
# 7   1      1   pass
# 8   1      0   fail
# 9   1      1   pass

# %%
entropy_results_guide_yes = -(4/5)*np.log2(4/5) -(1/5)*np.log2(1/5)
entropy_results_guide_yes
# Out:
# np.float64(0.7219280948873623)

# %%
data[data.guide == 0]
# Out:
#    yt  guide result
# 0   0      0   fail
# 2   1      0   pass
# 3   0      0   fail
# 4   0      0   fail
# 8   1      0   fail

# %%
entropy_results_guide_no = -(1/5)*np.log2(1/5) -(4/5)*np.log2(4/5)
entropy_results_guide_no
# Out:
# np.float64(0.7219280948873623)

# %%
guide_entropy = (5/10) * entropy_results_guide_yes +  (5/10) * entropy_results_guide_no
guide_entropy
# Out:
# np.float64(0.7219280948873623)

# %%
info_guide = entropy_results - guide_entropy
info_guide
# Out:
# np.float64(0.2780719051126377)

# %%
print(info_yt)
# Out:
# 0.6099865470109875

# %%
print(info_guide)
# Out:
# 0.2780719051126377

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df = data
df.result = le.fit_transform(df.result)
df
# Out:
#    yt  guide  result
# 0   0      0       0
# 1   1      1       1
# 2   1      0       1
# 3   0      0       0
# 4   0      0       0
# 5   1      1       1
# 6   0      1       0
# 7   1      1       1
# 8   1      0       0
# 9   1      1       1

# %%
x = df[['yt','guide']]
y = df['result']

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
dt = DecisionTreeClassifier(criterion='entropy')

# %%
dt.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
export_graphviz(dt,'dt.tree',feature_names=['yt','guide'])

# %%
dt.predict([[1,1]])
# Out:
# C:\Users\Abdul\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
dt.score(x,y)
# Out:
# 0.9
