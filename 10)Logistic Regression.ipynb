# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\Abdul\OneDrive\Documents\Python\Dataset\job.csv")
df.head(5)
# Out:
#    Years  result
# 0     22       0
# 1     25       0
# 2     47       1
# 3     52       0
# 4     46       1

# %%
x=df[['Years']]
y=df[['result']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y, train_size=0.8, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\Abdul\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
print(X_test)
# Out:
#     Years
# 17     58
# 14     49
# 18     19
# 3      52
# 23     45
# 10     18

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 1, 0])

# %%
y_test
# Out:
# 17    1
# 14    1
# 18    0
# 3     0
# 23    1
# 10    0
# Name: result, dtype: int64

# %%
model.score(X_test,Y_test)
# Out:
# 0.8333333333333334

# %%
import seaborn as sns
sns.regplot(x=x, y=y, logistic=True)
# Out:
# <Axes: xlabel='Years', ylabel='result'>
