# %%
from pandas import read_csv
data1 = read_csv(r"C:\Users\Abdul\OneDrive\Documents\Python\Dataset\age1.csv")
data1.head()
# Out:
#    Age  Income
# 0   20   10000
# 1   30   15000
# 2   80   50000
# 3   50   30000
# 4   10    5000

# %%
X=data1['Age']
Y=data1['Income']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2, random_state=1)

# %%
print(X_train, '\n')
print(X_test, '\n')
print(Y_train, '\n')
print(Y_test, '\n')
# Out:
# 6    30
# 4    10
# 0    20
# 3    50
# 1    30
# 7    55
# 8    60
# 5    45
# Name: Age, dtype: int64
#
# 2    80
# 9    70
# Name: Age, dtype: int64
#
# 6    20000
# 4     5000
# 0    10000
# 3    30000
# 1    15000
# 7    35000
# 8    40000
# 5    25000
# Name: Income, dtype: int64
#
# 2    50000
# 9    45000
# Name: Income, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2, random_state=1, shuffle=False)

# %%
print(X_train, '\n')
print(X_test, '\n')
print(Y_train, '\n')
print(Y_test, '\n')
# Out:
# 0    20
# 1    30
# 2    80
# 3    50
# 4    10
# 5    45
# 6    30
# 7    55
# Name: Age, dtype: int64
#
# 8    60
# 9    70
# Name: Age, dtype: int64
#
# 0    10000
# 1    15000
# 2    50000
# 3    30000
# 4     5000
# 5    25000
# 6    20000
# 7    35000
# Name: Income, dtype: int64
#
# 8    40000
# 9    45000
# Name: Income, dtype: int64
